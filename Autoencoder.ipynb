# %%
#Librabries
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
#Preprocessing
data = pd.read_csv('creditcard.csv')

print(f"Data shape : {data.shape}")
print(f"Fraudulent cases : {data[data['Class'] == 1].shape[0]}")
print(f"Normal cases : {data[data['Class'] == 0].shape[0]}")
# Out:
# Data shape : (284807, 31)
# Fraudulent cases : 492
# Normal cases : 284315

# %%
scaler = StandardScaler()
data['Amount'] = scaler.fit_transform(data['Amount'].values.reshape(-1,1))
data['Time'] = scaler.fit_transform(data['Time'].values.reshape(-1,1))

normal_data = data[data['Class'] == 0]
fraud_data = data[data['Class'] == 1]

normal_data = normal_data.drop('Class', axis=1)
fraud_data = fraud_data.drop('Class', axis=1)

x_train,x_val = train_test_split(normal_data, test_size=0.2,random_state=42)

x_train = x_train.values
x_val = x_val.values 
x_fraud = fraud_data.values

input_dim = x_train.shape[1]
print(f"Number of features (input dimension): {input_dim}")
# Out:
# Number of features (input dimension): 30

# %%
latent_dim = 8
auto = Sequential()
auto.add(Input(shape=(input_dim,)))
auto.add(Dense(64,activation='relu'))
auto.add(Dropout(0.1))
auto.add(Dense(32,activation='relu'))
auto.add(Dropout(0.1))
auto.add(Dense(16,activation='relu'))
auto.add(Dropout(0.1))
auto.add(Dense(latent_dim, activation='relu'))
auto.add(Dense(16,activation='relu'))
auto.add(Dropout(0.1))
auto.add(Dense(32,activation='relu'))
auto.add(Dropout(0.1))
auto.add(Dense(64,activation='relu'))
auto.add(Dense(30,activation='linear'))

# %%
auto.compile(optimizer='adam',
                    loss='mean_squared_error',
                    metrics=['mae'])

auto.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │           1,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 16)                  │             144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 32)                  │             544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 30)                  │           1,950 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9,478 (37.02 KB)
#  Trainable params: 9,478 (37.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = auto.fit(
    x_train,x_train,
    epochs=50,
    batch_size=32,
    shuffle=True,
    validation_data=(x_val,x_val)
)
# Out:
# Epoch 1/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step - loss: 0.7022 - mae: 0.5465 - val_loss: 0.4689 - val_mae: 0.4622
# Epoch 2/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 0.5357 - mae: 0.4889 - val_loss: 0.4378 - val_mae: 0.4433
# Epoch 3/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 0.4961 - mae: 0.4730 - val_loss: 0.4052 - val_mae: 0.4287
# Epoch 4/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 0.4745 - mae: 0.4635 - val_loss: 0.3978 - val_mae: 0.4234
# Epoch 5/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - loss: 0.4615 - mae: 0.4580 - val_loss: 0.3927 - val_mae: 0.4215
# Epoch 6/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 0.4599 - mae: 0.4558 - val_loss: 0.3765 - val_mae: 0.4146
# Epoch 7/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 0.4513 - mae: 0.4513 - val_loss: 0.3725 - val_mae: 0.4126
# Epoch 8/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - loss: 0.4378 - mae: 0.4467 - val_loss: 0.3530 - val_mae: 0.4037
# Epoch 9/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - loss: 0.4388 - mae: 0.4462 - val_loss: 0.3599 - val_mae: 0.4055
# Epoch 10/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 0.4291 - mae: 0.4425 - val_loss: 0.3519 - val_mae: 0.4030
# Epoch 11/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 0.4307 - mae: 0.4420 - val_loss: 0.3668 - val_mae: 0.4058
# Epoch 12/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 0.4301 - mae: 0.4403 - val_loss: 0.3730 - val_mae: 0.4081
# Epoch 13/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 0.4158 - mae: 0.4375 - val_loss: 0.3554 - val_mae: 0.4012
# Epoch 14/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - loss: 0.4181 - mae: 0.4368 - val_loss: 0.3507 - val_mae: 0.3996
# Epoch 15/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - loss: 0.4195 - mae: 0.4370 - val_loss: 0.3546 - val_mae: 0.4006
# Epoch 16/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - loss: 0.4164 - mae: 0.4358 - val_loss: 0.3604 - val_mae: 0.4037
# Epoch 17/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - loss: 0.4152 - mae: 0.4351 - val_loss: 0.3468 - val_mae: 0.3974
# Epoch 18/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - loss: 0.4131 - mae: 0.4339 - val_loss: 0.3412 - val_mae: 0.3939
# Epoch 19/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.4114 - mae: 0.4334 - val_loss: 0.3492 - val_mae: 0.3985
# Epoch 20/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.4129 - mae: 0.4331 - val_loss: 0.3393 - val_mae: 0.3949
# Epoch 21/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.4169 - mae: 0.4333 - val_loss: 0.3469 - val_mae: 0.3962
# Epoch 22/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.4165 - mae: 0.4324 - val_loss: 0.3518 - val_mae: 0.3985
# Epoch 23/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.4097 - mae: 0.4312 - val_loss: 0.3453 - val_mae: 0.3973
# Epoch 24/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - loss: 0.4078 - mae: 0.4306 - val_loss: 0.3481 - val_mae: 0.3964
# Epoch 25/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - loss: 0.4052 - mae: 0.4300 - val_loss: 0.3388 - val_mae: 0.3947
# Epoch 26/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.4021 - mae: 0.4288 - val_loss: 0.3521 - val_mae: 0.3973
# Epoch 27/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.4073 - mae: 0.4296 - val_loss: 0.3476 - val_mae: 0.3941
# Epoch 28/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.4080 - mae: 0.4292 - val_loss: 0.3375 - val_mae: 0.3953
# Epoch 29/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - loss: 0.4045 - mae: 0.4285 - val_loss: 0.3550 - val_mae: 0.3943
# Epoch 30/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.4067 - mae: 0.4288 - val_loss: 0.3402 - val_mae: 0.3931
# Epoch 31/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.4007 - mae: 0.4274 - val_loss: 0.3399 - val_mae: 0.3930
# Epoch 32/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.4028 - mae: 0.4273 - val_loss: 0.3450 - val_mae: 0.3950
# Epoch 33/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.4069 - mae: 0.4280 - val_loss: 0.3439 - val_mae: 0.3921
# Epoch 34/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.4007 - mae: 0.4262 - val_loss: 0.3295 - val_mae: 0.3899
# Epoch 35/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.3982 - mae: 0.4255 - val_loss: 0.3280 - val_mae: 0.3888
# Epoch 36/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.3992 - mae: 0.4249 - val_loss: 0.3436 - val_mae: 0.3918
# Epoch 37/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.3986 - mae: 0.4255 - val_loss: 0.3381 - val_mae: 0.3925
# Epoch 38/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - loss: 0.3955 - mae: 0.4248 - val_loss: 0.3421 - val_mae: 0.3960
# Epoch 39/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.4021 - mae: 0.4253 - val_loss: 0.3479 - val_mae: 0.3927
# Epoch 40/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.3946 - mae: 0.4236 - val_loss: 0.3267 - val_mae: 0.3868
# Epoch 41/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.3917 - mae: 0.4223 - val_loss: 0.3273 - val_mae: 0.3862
# Epoch 42/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.3986 - mae: 0.4233 - val_loss: 0.3493 - val_mae: 0.3935
# Epoch 43/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.4008 - mae: 0.4249 - val_loss: 0.3326 - val_mae: 0.3893
# Epoch 44/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.3934 - mae: 0.4226 - val_loss: 0.3305 - val_mae: 0.3883
# Epoch 45/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.3999 - mae: 0.4232 - val_loss: 0.3365 - val_mae: 0.3898
# Epoch 46/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.3965 - mae: 0.4230 - val_loss: 0.3387 - val_mae: 0.3897
# Epoch 47/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.3983 - mae: 0.4235 - val_loss: 0.3393 - val_mae: 0.3912
# Epoch 48/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.3968 - mae: 0.4219 - val_loss: 0.3447 - val_mae: 0.3914
# Epoch 49/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.3887 - mae: 0.4203 - val_loss: 0.3291 - val_mae: 0.3863
# Epoch 50/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.3920 - mae: 0.4213 - val_loss: 0.3340 - val_mae: 0.3875

# %%
resconstruction_val = auto.predict(x_val)
val_loss = tf.keras.losses.mae(resconstruction_val,x_val)

resconstruction_fraud = auto.predict(x_fraud)
fraud_loss = tf.keras.losses.mae(resconstruction_fraud,x_fraud)

print(f"val_loss : {np.mean(val_loss)} , fraud_loss : {np.mean(fraud_loss)}")
# Out:
# 1777/1777 ━━━━━━━━━━━━━━━━━━━━ 2s 949us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# val_loss : 0.38747856910099193 , fraud_loss : 1.5190453419036365

# %%
threshold = np.mean(val_loss) + 3*np.std(val_loss)
print(f"\nReconstruction Error Threshold (MAE) : {threshold}")

anomalies = fraud_loss > threshold  
print(f"\nTotal fraudulent transactions : {len(x_fraud)}")
print(f"Frauds detected as anomalies (loss > treshold): {np.sum(anomalies)}")
print(f"Detection Rate : {np.sum(anomalies)/ len(x_fraud) * 100 :.2f}%")
# Out:
# Reconstruction Error Threshold (MAE) : 0.9568192776362705
#
# Total fraudulent transactions : 492
# Frauds detected as anomalies (loss > treshold): 386
# Detection Rate : 78.46%
