# %%
#Librabries
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
#Preprocessing
data = pd.read_csv('creditcard.csv')

print(f"Data shape : {data.shape}")
print(f"Fraudulent cases : {data[data['Class'] == 1].shape[0]}")
print(f"Normal cases : {data[data['Class'] == 0].shape[0]}")
# Out:
# Data shape : (284807, 31)
# Fraudulent cases : 492
# Normal cases : 284315

# %%
scaler = StandardScaler()
data['Amount'] = scaler.fit_transform(data['Amount'].values.reshape(-1,1))
data['Time'] = scaler.fit_transform(data['Time'].values.reshape(-1,1))

normal_data = data[data['Class'] == 0]
fraud_data = data[data['Class'] == 1]

normal_data = normal_data.drop('Class', axis=1)
fraud_data = fraud_data.drop('Class', axis=1)

x_train,x_val = train_test_split(normal_data, test_size=0.2,random_state=42)

x_train = x_train.values
x_val = x_val.values 
x_fraud = fraud_data.values

input_dim = x_train.shape[1]
print(f"Number of features (input dimension): {input_dim}")
# Out:
# Number of features (input dimension): 30

# %%
latent_dim = 8
input_layer = Input(shape=(input_dim,))

encoder = Dense(64,activation='relu')(input_layer)
encoder = Dropout(0.1)(encoder)
encoder = Dense(32,activation='relu')(encoder)
encoder = Dropout(0.1)(encoder)
encoder = Dense(16,activation='relu')(encoder)
encoder = Dropout(0.1)(encoder)
encoder = Dense(latent_dim, activation='relu')(encoder)

# %%
decoder = Dense(16,activation='relu')(encoder)
decoder = Dropout(0.1)(decoder)
decoder = Dense(32,activation='relu')(decoder)
decoder = Dropout(0.1)(decoder)
decoder = Dense(64,activation='relu')(decoder)
decoder = Dropout(0.1)(decoder)
decoder = Dense(input_dim, activation='linear')(decoder)

autoencoder = Model(inputs= input_layer,outputs=decoder)

# %%
autoencoder.compile(optimizer='adam',
                    loss='mean_squared_error',
                    metrics=['mae'])

autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 30)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 16)                  │             496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 16)                  │             144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 32)                  │             544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 30)                  │           1,950 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,382 (21.02 KB)
#  Trainable params: 5,382 (21.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = autoencoder.fit(
    x_train,x_train,
    epochs=50,
    batch_size=32,
    shuffle=True,
    validation_data=(x_val,x_val)
)
# Out:
# Epoch 1/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 18s 3ms/step - loss: 0.3618 - mae: 0.3994 - val_loss: 0.2491 - val_mae: 0.3366
# Epoch 2/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.3682 - mae: 0.4015 - val_loss: 0.2607 - val_mae: 0.3422
# Epoch 3/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.3645 - mae: 0.3999 - val_loss: 0.2522 - val_mae: 0.3366
# Epoch 4/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.3657 - mae: 0.3997 - val_loss: 0.2509 - val_mae: 0.3354
# Epoch 5/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.3629 - mae: 0.4002 - val_loss: 0.2611 - val_mae: 0.3400
# Epoch 6/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.3653 - mae: 0.3998 - val_loss: 0.2511 - val_mae: 0.3369
# Epoch 7/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.3656 - mae: 0.4005 - val_loss: 0.2692 - val_mae: 0.3516
# Epoch 8/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.3672 - mae: 0.4008 - val_loss: 0.2537 - val_mae: 0.3372
# Epoch 9/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.3646 - mae: 0.4000 - val_loss: 0.2547 - val_mae: 0.3413
# Epoch 10/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.3611 - mae: 0.3997 - val_loss: 0.2611 - val_mae: 0.3410
# Epoch 11/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.3655 - mae: 0.3996 - val_loss: 0.2540 - val_mae: 0.3383
# Epoch 12/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.3671 - mae: 0.4001 - val_loss: 0.2629 - val_mae: 0.3423
# Epoch 13/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.3653 - mae: 0.3998 - val_loss: 0.2692 - val_mae: 0.3477
# Epoch 14/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.3671 - mae: 0.4003 - val_loss: 0.2568 - val_mae: 0.3387
# Epoch 15/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - loss: 0.3622 - mae: 0.3983 - val_loss: 0.2553 - val_mae: 0.3400
# Epoch 16/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.3612 - mae: 0.3986 - val_loss: 0.2511 - val_mae: 0.3354
# Epoch 17/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.3642 - mae: 0.3993 - val_loss: 0.2605 - val_mae: 0.3409
# Epoch 18/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - loss: 0.3649 - mae: 0.3988 - val_loss: 0.2688 - val_mae: 0.3435
# Epoch 19/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - loss: 0.3669 - mae: 0.3994 - val_loss: 0.2475 - val_mae: 0.3344
# Epoch 20/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 25s 4ms/step - loss: 0.3644 - mae: 0.3985 - val_loss: 0.2581 - val_mae: 0.3404
# Epoch 21/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.3662 - mae: 0.3995 - val_loss: 0.2572 - val_mae: 0.3369
# Epoch 22/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - loss: 0.3633 - mae: 0.3989 - val_loss: 0.2508 - val_mae: 0.3379
# Epoch 23/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - loss: 0.3615 - mae: 0.3991 - val_loss: 0.2457 - val_mae: 0.3345
# Epoch 24/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - loss: 0.3630 - mae: 0.3988 - val_loss: 0.2607 - val_mae: 0.3398
# Epoch 25/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - loss: 0.3646 - mae: 0.3986 - val_loss: 0.2532 - val_mae: 0.3388
# Epoch 26/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - loss: 0.3609 - mae: 0.3978 - val_loss: 0.2546 - val_mae: 0.3379
# Epoch 27/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.3599 - mae: 0.3985 - val_loss: 0.2674 - val_mae: 0.3429
# Epoch 28/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.3652 - mae: 0.3987 - val_loss: 0.2555 - val_mae: 0.3404
# Epoch 29/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.3626 - mae: 0.3983 - val_loss: 0.2555 - val_mae: 0.3392
# Epoch 30/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.3677 - mae: 0.3992 - val_loss: 0.2486 - val_mae: 0.3359
# Epoch 31/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.3628 - mae: 0.3984 - val_loss: 0.2565 - val_mae: 0.3387
# Epoch 32/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 0.3576 - mae: 0.3972 - val_loss: 0.2507 - val_mae: 0.3373
# Epoch 33/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 0.3605 - mae: 0.3976 - val_loss: 0.2529 - val_mae: 0.3360
# Epoch 34/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 0.3573 - mae: 0.3970 - val_loss: 0.2502 - val_mae: 0.3351
# Epoch 35/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - loss: 0.3618 - mae: 0.3976 - val_loss: 0.2517 - val_mae: 0.3346
# Epoch 36/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 24s 3ms/step - loss: 0.3665 - mae: 0.3988 - val_loss: 0.2543 - val_mae: 0.3386
# Epoch 37/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 0.3618 - mae: 0.3992 - val_loss: 0.2577 - val_mae: 0.3388
# Epoch 38/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - loss: 0.3613 - mae: 0.3970 - val_loss: 0.2445 - val_mae: 0.3310
# Epoch 39/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.3592 - mae: 0.3966 - val_loss: 0.2583 - val_mae: 0.3372
# Epoch 40/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.3639 - mae: 0.3983 - val_loss: 0.2453 - val_mae: 0.3339
# Epoch 41/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.3622 - mae: 0.3973 - val_loss: 0.2561 - val_mae: 0.3411
# Epoch 42/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 19s 3ms/step - loss: 0.3642 - mae: 0.3983 - val_loss: 0.2568 - val_mae: 0.3381
# Epoch 43/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.3600 - mae: 0.3973 - val_loss: 0.2514 - val_mae: 0.3346
# Epoch 44/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.3628 - mae: 0.3975 - val_loss: 0.2588 - val_mae: 0.3401
# Epoch 45/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 23s 3ms/step - loss: 0.3605 - mae: 0.3976 - val_loss: 0.2556 - val_mae: 0.3396
# Epoch 46/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.3607 - mae: 0.3975 - val_loss: 0.2529 - val_mae: 0.3385
# Epoch 47/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.3663 - mae: 0.3986 - val_loss: 0.2585 - val_mae: 0.3371
# Epoch 48/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.3641 - mae: 0.3978 - val_loss: 0.2544 - val_mae: 0.3398
# Epoch 49/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.3571 - mae: 0.3965 - val_loss: 0.2450 - val_mae: 0.3357
# Epoch 50/50
# 7108/7108 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - loss: 0.3624 - mae: 0.3974 - val_loss: 0.2715 - val_mae: 0.3472

# %%
resconstruction_val = autoencoder.predict(x_val)
val_loss = tf.keras.losses.mae(resconstruction_val,x_val)

resconstruction_fraud = autoencoder.predict(x_fraud)
fraud_loss = tf.keras.losses.mae(resconstruction_fraud,x_fraud)

print(f"val_loss : {np.mean(val_loss)} , fraud_loss : {np.mean(fraud_loss)}")
# Out:
# 1777/1777 ━━━━━━━━━━━━━━━━━━━━ 1s 603us/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# val_loss : 0.33761522004925754 , fraud_loss : 1.7308246822637106

# %%
threshold = np.mean(val_loss) + 3*np.std(val_loss)
print(f"\nReconstruction Error Threshold (MAE) : {threshold}")

anomalies = fraud_loss > threshold  
print(f"\nTotal fraudulent transactions : {len(x_fraud)}")
print(f"Frauds detected as anomalies (loss > treshold): {np.sum(anomalies)}")
print(f"Detection Rate : {np.sum(anomalies)/ len(x_fraud) * 100 :.2f}%")
# Out:
# Reconstruction Error Threshold (MAE) : 0.8754864534431288
#
# Total fraudulent transactions : 492
# Frauds detected as anomalies (loss > treshold): 400
# Detection Rate : 81.30%
